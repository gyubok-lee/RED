# %%
from red.red import RED
from red.portfolio import Portfolio
import Industry_Analysis as Industry
import pandas as pd

# %%
user = RED()
user.run()
# Out:
# 입력이 완료되었습니다, 투자자 성향을 판단중입니다
# ···
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=613x677 at 0x1FE4E9FF388>
# 추천 주식 종목 찾는 중...
# 추천 ETF 찾는 중...
#
#
# 고객님의 포트폴리오입니다.
#
#
# 주식 종목 : 1799740.0원
#
# 키움증권, 2개 매입. bollinger 전략. 현재가: 126000.0
# NH투자증권, 18개 매입. bollinger 전략. 현재가: 10850.0
# 삼성증권, 4개 매입. bollinger 전략. 현재가: 36250.0
# 더블유게임즈, 3개 매입. bollinger 전략. 현재가: 55300.0
# 알서포트, 21개 매입. bollinger 전략. 현재가: 8320.0
# 파마리서치프로덕트, 3개 매입. bollinger 전략. 현재가: 55800.0
# 인트론바이오, 9개 매입. bollinger 전략. 현재가: 19650.0
# 미래에셋대우, 19개 매입. bollinger 전략. 현재가: 9330.0
# 이엔에프테크놀로지, 4개 매입. bollinger 전략. 현재가: 41700.0
# 디앤씨미디어, 5개 매입. bollinger 전략. 현재가: 35700.0
#
# 채권 ETF 종목 : 0.0원
#
#
# 일반 ETF 종목 : 1194225.0원
#
# TIGER 200 산업재, 44개 매입. 20일 후 리밸런싱 권장. 현재가: 5875.0
# KODEX 미국러셀2000(H), 17개 매입. 20일 후 리밸런싱 권장. 현재가: 14055.0
# ARIRANG 미국다우존스고배당주(합성 H), 17개 매입. 20일 후 리밸런싱 권장. 현재가: 13970.0
# TIGER 소프트웨어, 14개 매입. 20일 후 리밸런싱 권장. 현재가: 16530.0
# KINDEX 일본Nikkei225(H), 12개 매입. 20일 후 리밸런싱 권장. 현재가: 18990.0
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1073x523 at 0x1FE4DFD33C8>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1068x76 at 0x1FE4EA3E348>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1066x76 at 0x1FE4DFE0208>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1065x523 at 0x1FE4EA3E3C8>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1065x523 at 0x1FE4E2A3BC8>
# Button(description='결과 저장', style=ButtonStyle())

# %%
user.rec_stocks
# Out:
# [['키움증권', 126000.0, 'bollinger', 3, 0.021981401441330515],
#  ['NH투자증권', 10850.0, 'bollinger', 3, 0.04070097920447776],
#  ['삼성증권', 36250.0, 'bollinger', 3, 0.03812953603371495],
#  ['더블유게임즈', 55300.0, 'bollinger', 3, 0.04054810904999209],
#  ['알서포트', 8320.0, 'bollinger', 3, 0.022963975459390565],
#  ['파마리서치프로덕트', 55800.0, 'bollinger', 3, 0.0421294548238986],
#  ['인트론바이오', 19650.0, 'bollinger', 3, 0.0462986416126427],
#  ['미래에셋대우', 9330.0, 'bollinger', 3, 0.04084469046969774],
#  ['이엔에프테크놀로지', 41700.0, 'bollinger', 3, 0.020457918748558224],
#  ['디앤씨미디어', 35700.0, 'bollinger', 3, 0.028397726774422132],
#  ['컴투스', 138000.0, 'bollinger', 3, 0.031731278922570924],
#  ['HDC현대산업개발', 26650.0, 'mfi', 1.65, 0.059871061553490985],
#  ['네오위즈', 21800.0, 'bollinger', 3, 0.046505265908769175],
#  ['금호석유', 205500.0, 'bollinger', 3, 0.022099121299962634],
#  ['웹케시', 70000.0, 'bollinger', 3, 0.04023146302668406],
#  ['유비쿼스홀딩스', 21250.0, 'bollinger', 3, 0.029349120771719577],
#  ['코웨이', 64900.0, 'bollinger', 3, 0.03380708104894874],
#  ['테스나', 47700.0, 'bollinger', 3, 0.017007096717126545],
#  ['제이앤티씨', 10050.0, 'bollinger', 3, 0.07324719396265952],
#  ['미코', 14200.0, 'bollinger', 3, 0.01714725886106735],
#  ['삼양사', 54300.0, 'bollinger', 3, 0.04921674511692159],
#  ['에스앤에스텍', 34500.0, 'bollinger', 3, 0.013983064112097798],
#  ['삼양식품', 87000.0, 'bollinger', 3, 0.025452703331811884],
#  ['오이솔루션', 45000.0, 'bollinger', 3, 0.024602706484721047],
#  ['두산', 46450.0, 'bollinger', 3, 0.06876849914039664],
#  ['만도', 61500.0, 'mfi', 1.65, 0.028335768682751384],
#  ['비에이치', 17750.0, 'mfi', 1.65, 0.03108287361517776],
#  ['아이티엠반도체', 45300.0, 'bollinger', 3, 0.07320846970369188],
#  ['지누스', 91500.0, 'mfi', 1.65, 0.049689113972900344],
#  ['유비케어', 8060.0, 'bollinger', 3, 0.02435794455490835],
#  ['녹십자랩셀', 88800.0, 'mfi', 1.65, 0.0324484591428763],
#  ['롯데정밀화학', 51800.0, 'bollinger', 3, 0.0336862478791773],
#  ['엘비세미콘', 12000.0, 'bollinger', 3, 0.021173007708128366],
#  ['LG화학', 830000.0, 'bollinger', 3, 0.016537793354433776],
#  ['동화기업', 48200.0, 'bollinger', 3, 0.019624932247944035],
#  ['삼성SDI', 670000.0, 'bollinger', 3, 0.011513157144463911],
#  ['한온시스템', 15300.0, 'bollinger', 3, 0.02108386283809165],
#  ['삼강엠앤티', 16350.0, 'bollinger', 3, 0.020774483396811212],
#  ['아미코젠', 28200.0, 'bollinger', 3, 0.05845369301780405],
#  ['대주전자재료', 39000.0, 'bollinger', 3, 0.019148886902243565],
#  ['한화에어로스페이스', 36550.0, 'bollinger', 3, 0.04898451322508758],
#  ['LS ELECTRIC', 56800.0, 'bollinger', 3, 0.03440384977960525],
#  ['대상', 24700.0, 'bollinger', 3, 0.042745273559558414],
#  ['다원시스', 19300.0, 'bollinger', 3, 0.030721736445062434],
#  ['두산퓨얼셀', 50100.0, 'bollinger', 3, 0.04737690676211769],
#  ['포스코 ICT', 7460.0, 'bollinger', 3, 0.03109173787445286],
#  ['농심', 274000.0, 'bollinger', 3, 0.03130809287628844],
#  ['상아프론테크', 44250.0, 'bollinger', 3, 0.01610338070510308],
#  ['후성', 9970.0, 'bollinger', 3, 0.03221095012688468],
#  ['에코프로비엠', 160100.0, 'mfi', 1.65, 0.032617816351813066],
#  ['에코프로비엠', 160100.0, 'bollinger', 3, 0.032617816351813066],
#  ['롯데칠성', 113500.0, 'bollinger', 3, 0.04254029788286519],
#  ['한화', 29100.0, 'bollinger', 3, 0.04130444831963356],
#  ['LG하우시스', 70600.0, 'bollinger', 3, 0.05140754080009969],
#  ['부광약품', 26500.0, 'long_candle', 2.16, 0.02202216353036227],
#  ['부광약품', 26500.0, 'AA', 3.1, 0.02202216353036227],
#  ['영진약품', 6340.0, 'rsi_sto', 3.67, 0.041017766055136],
#  ['네패스', 38850.0, 'bollinger', 3, 0.020045968617142296],
#  ['CJ', 90700.0, 'bollinger', 3, 0.05227329353662264],
#  ['JW중외제약', 28600.0, 'bollinger', 3, 0.046168299699055705],
#  ['에이치엘비생명과학', 17950.0, 'rsi_sto', 3.67, 0.03673090637430017],
#  ['성우하이텍', 6440.0, 'bollinger', 3, 0.0528361072729929],
#  ['와이팜', 10500.0, 'bollinger', 3, 0.07360021092394482],
#  ['쏠리드', 8680.0, 'bollinger', 3, 0.03005864740343395],
#  ['아난티', 7250.0, 'bollinger', 3, 0.05364502577300938],
#  ['네패스아크', 43850.0, 'bollinger', 3, 0.07303459890946294],
#  ['카이노스메드', 3905.0, 'bollinger', 3, 0.03132679105483283],
#  ['에이치엘비', 68200.0, 'rsi_sto', 3.67, 0.03777190152387848],
#  ['코오롱티슈진', 8010.0, 'mfi', 1.65, 0.17375620756293186],
#  ['신라젠', 12100.0, 'mfi', 1.65, 0.27635822362066637]]

# %%
Portfolio().calculate_return()
users_now = pd.read_csv("./data/users/userDB.csv", index_col = 0, encoding= "cp949")
users_now
# Out:
#                                                  ETF 관심산업분야  \
# 0  [('KBSTAR 200IT', [3, [14985.0, 0.65, 1.21, 0....     IT
# 1  [('TIGER 200 철강소재', [16, [7260.0, 0.6, 1.21, 0...   철강금속
# 2  [('KBSTAR 200건설', [26, [10735.0, 0.7, 1.21, 0....     건설
# 3  [('KODEX 2차전지산업', [1, [19570.0, 1.58, 1.21, 0....     화학
#
#                                               금융지식수준  나이          날짜 성별  \
# 0  널리 알려진 금융투자 상품(주식, 채권 및 펀드 등)의 구조 및 위험을 깊이 있게 ...  24  2020-12-28  남
# 1                               금융투자상품에 투자해 본 경험이 없음  24  2020-12-29  남
# 2                               금융투자상품에 투자해 본 경험이 없음  20  2021-01-15  남
# 3            파생상품을 포함한 대부분의 금융투자상품의 구조 및 위험을 이해하고 있음  20  2021-01-22  남
#
#     수익률 기준 날짜  월 정기 수입(만 원)  \
# 0  20210216.0         100.0
# 1  20210216.0           0.0
# 2  20210216.0         100.0
# 3  20210216.0         100.0
#
#                                               위험추구성향  \
# 0  시장 평균 수익률을 넘어서는 높은 수준의 투자 수익 추구 / 투자자금의 대부분을 주...
# 1       예금ㆍ적금보다 높은 수익을 기대할 수 있다면 위험을 감수하고 투자할 의향이 있음
# 2  투자원금의 보전보다 수익을 추구 / 투자자금의 대부분을 주식, 옵션 등의 위험자산에...
# 3  시장 평균 수익률을 넘어서는 높은 수준의 투자 수익 추구 / 투자자금의 대부분을 주...
#
#                                                   주식  채권  투자 금액(만 원)  \
# 0  [('유비쿼스홀딩스', [2, [27050.0, 'mfi', 1.65, 0.0227...  []         100
# 1  [('바디텍메드', [2, [23850.0, 'r_sigma', 1.95, 0.05...  []         200
# 2  [('대림산업', [2, [83000.0, 'mfi', 1.65, 0.0417506...  []         300
# 3  [('웹젠', [2, [42450.0, 'long_candle', 2.16, 0.0...  []          60
#
#       투자 기간  현재 수익률(%)
# 0  1주 ~ 1개월      27.06
# 1  1주 ~ 1개월      24.91
# 2  1주 ~ 1개월      -1.84
# 3  1주 ~ 1개월      -1.51

# %%
Industry.industry_analysis()
# Out:
# 산업간 양(+)의 상관관계가 총 3개 발견되었습니다.
#
# 산업간 음(-)의 상관관계가 총 3개 발견되었습니다.
